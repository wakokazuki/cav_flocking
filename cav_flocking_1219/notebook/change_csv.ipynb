# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import os
import csv
import pathlib
import operator 
from operator import itemgetter


plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = 'Arial'
# plt.rcParams['font.family'] = 'Meiryo'

# %%
#csvファイルの選択基準
method_label = "nsga3"
pop_num = 120

#csvファイルの選択
list_of_files = glob.glob(f'../out/csv/csv0324/*')
for file in list_of_files:
    print(file)
# Out:
# ../out/csv/csv0324/loop00_pop120_gen108_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen195_ctaea.csv
# ../out/csv/csv0324/loop00_pop120_gen278_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen73_ctaea.csv
# ../out/csv/csv0324/loop00_pop120_gen27_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen153_nsga3.csv
# ../out/csv/csv0324/loop00_pop120_gen1_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen223_nsga3.csv
# ../out/csv/csv0324/loop00_pop120_gen256_ctaea.csv
# ../out/csv/csv0324/loop00_pop120_gen202_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen172_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen126_ctaea.csv
# ../out/csv/csv0324/loop00_pop120_gen259_nsga3.csv
# ../out/csv/csv0324/loop00_pop120_gen290_nsga3.csv
# ../out/csv/csv0324/loop00_pop120_gen129_nsga3.csv
# ../out/csv/csv0324/loop00_pop120_gen94_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen80_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen49_nsga2.csv
# ../out/csv/csv0324/loop00_pop120_gen284_nsga3.csv
# ...

# %%
#csvファイルの並び替えの関数
def sort_csv(csv_file: pathlib, sort_row1: int,sort_row2:int):
    # 今回作成したuser_list_csvを開く
    csv_data = csv.reader(open(csv_file), delimiter=',')
    # ヘッダー情報を取得
    header = next(csv_data)
    # ヘッダー以外の列を並び替える
    sort_result = sorted(csv_data, key=itemgetter(sort_row1,sort_row2))
    #print(sort_result)
    # 新規ファイルとしてuser_list_csvを開く
    with open(csv_file, "w") as f:
        # ヘッダーと並び替え結果をファイルに書き込む
        data = csv.writer(f, delimiter=',')
        data.writerow(header)
        for r in sort_result:
            data.writerow(r)

#csvファイルの並び替えの繰り返し
for file in list_of_files:
    sort_csv(file,13,14)
